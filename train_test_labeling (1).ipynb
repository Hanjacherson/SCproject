# %%
import os
import random
import shutil
import math

def split_files(source_folder, train_folder, test_folder, split_ratio):
    
    # 대상 폴더들이 없으면 생성
    if not os.path.exists(train_folder):
        os.makedirs(train_folder)
    if not os.path.exists(test_folder):
        os.makedirs(test_folder)
    
    # train 폴더 안에 barking과 whining 폴더 생성
    train_barking_folder = os.path.join(train_folder, 'barking')
    train_whining_folder = os.path.join(train_folder, 'whining')
    if not os.path.exists(train_barking_folder):
        os.makedirs(train_barking_folder)
    
    if not os.path.exists(train_whining_folder):
        os.makedirs(train_whining_folder)
    
    # test 폴더 안에 barking과 whining 폴더 생성
    test_barking_folder = os.path.join(test_folder, 'barking')
    test_whining_folder = os.path.join(test_folder, 'whining')
    if not os.path.exists(test_barking_folder):
        os.makedirs(test_barking_folder)
    
    if not os.path.exists(test_whining_folder):
        os.makedirs(test_whining_folder)

    
    # 소스 폴더 내의 모든 파일 리스트 가져오기
    source_list = os.listdir(source_folder)
    
    # 파일을 랜덤하게 섞음
    random.shuffle(source_list)
    # 분할 인덱스 계산 (소수점 올림)
    split_index = math.ceil(len(source_list) * split_ratio)

    
    # 80%의 파일을 train 폴더로 이동 또는 복사
    for file_name in source_list[:split_index]:
        source_file = os.path.join(source_folder, file_name)
        if 'whining' in file_name:
            destination_file = os.path.join(train_whining_folder, file_name)
        else:
            destination_file = os.path.join(train_barking_folder, file_name)
        if os.path.isfile(source_file):
            shutil.move(source_file, destination_file)
            print(f"{source_file}을(를) {destination_file}로 이동했습니다.")
    
    # 20%의 파일을 test 폴더로 이동 또는 복사
    for file_name in source_list[split_index:]:
        source_file = os.path.join(source_folder, file_name)
        if 'whining' in file_name:
            destination_file = os.path.join(test_whining_folder, file_name)
        else:
            destination_file = os.path.join(test_barking_folder, file_name)
        if os.path.isfile(source_file):
            shutil.move(source_file, destination_file)
            print(f"{source_file}을(를) {destination_file}로 이동했습니다.")
       

# 원본 폴더 경로
whining_folder = './whining_2'
barking_folder = './barking_2'

# train 폴더 경로
train_folder = './train4'

# test 폴더 경로
test_folder = './test4'

# 분할 비율 (0.8: train, 0.2: test)
split_ratio = 0.8

# 파일 분할 실행
split_files(whining_folder, train_folder, test_folder, split_ratio)
split_files(barking_folder, train_folder, test_folder, split_ratio)
# Out:
# ./whining_2/whining (429).wav을(를) ./train4/whining/whining (429).wav로 이동했습니다.
# ./whining_2/whining (131).wav을(를) ./train4/whining/whining (131).wav로 이동했습니다.
# ./whining_2/whining (98).wav을(를) ./train4/whining/whining (98).wav로 이동했습니다.
# ./whining_2/whining (158).wav을(를) ./train4/whining/whining (158).wav로 이동했습니다.
# ./whining_2/whining (222).wav을(를) ./train4/whining/whining (222).wav로 이동했습니다.
# ./whining_2/whining (246).wav을(를) ./train4/whining/whining (246).wav로 이동했습니다.
# ./whining_2/whining (275).wav을(를) ./train4/whining/whining (275).wav로 이동했습니다.
# ./whining_2/whining (406).wav을(를) ./train4/whining/whining (406).wav로 이동했습니다.
# ./whining_2/whining (72).wav을(를) ./train4/whining/whining (72).wav로 이동했습니다.
# ./whining_2/whining (207).wav을(를) ./train4/whining/whining (207).wav로 이동했습니다.
# ./whining_2/whining (379).wav을(를) ./train4/whining/whining (379).wav로 이동했습니다.
# ./whining_2/whining (37).wav을(를) ./train4/whining/whining (37).wav로 이동했습니다.
# ./whining_2/whining (336).wav을(를) ./train4/whining/whining (336).wav로 이동했습니다.
# ./whining_2/whining (374).wav을(를) ./train4/whining/whining (374).wav로 이동했습니다.
# ./whining_2/whining (350).wav을(를) ./train4/whining/whining (350).wav로 이동했습니다.
# ./whining_2/whining (272).wav을(를) ./train4/whining/whining (272).wav로 이동했습니다.
# ./whining_2/whining (11).wav을(를) ./train4/whining/whining (11).wav로 이동했습니다.
# ./whining_2/whining (250).wav을(를) ./train4/whining/whining (250).wav로 이동했습니다.
# ./whining_2/whining (24).wav을(를) ./train4/whining/whining (24).wav로 이동했습니다.
# ./whining_2/whining (208).wav을(를) ./train4/whining/whining (208).wav로 이동했습니다.
# ./whining_2/whining (289).wav을(를) ./train4/whining/whining (289).wav로 이동했습니다.
# ./whining_2/whining (26).wav을(를) ./train4/whining/whining (26).wav로 이동했습니다.
# ./whining_2/whining (282).wav을(를) ./train4/whining/whining (282).wav로 이동했습니다.
# ./whining_2/whining (150).wav을(를) ./train4/whining/whining (150).wav로 이동했습니다.
# ./whining_2/whining (202).wav을(를) ./train4/whining/whining (202).wav로 이동했습니다.
# ./whining_2/whining (426).wav을(를) ./train4/whining/whining (426).wav로 이동했습니다.
# ./whining_2/whining (356).wav을(를) ./train4/whining/whining (356).wav로 이동했습니다.
# ./whining_2/whining (270).wav을(를) ./train4/whining/whining (270).wav로 이동했습니다.
# ./whining_2/whining (43).wav을(를) ./train4/whining/whining (43).wav로 이동했습니다.
# ./whining_2/whining (231).wav을(를) ./train4/whining/whining (231).wav로 이동했습니다.
# ./whining_2/whining (57).wav을(를) ./train4/whining/whining (57).wav로 이동했습니다.
# ./whining_2/whining (319).wav을(를) ./train4/whining/whining (319).wav로 이동했습니다.
# ./whining_2/whining (316).wav을(를) ./train4/whining/whining (316).wav로 이동했습니다.
# ./whining_2/whining (210).wav을(를) ./train4/whining/whining (210).wav로 이동했습니다.
# ./whining_2/whining (273).wav을(를) ./train4/whining/whining (273).wav로 이동했습니다.
# ./whining_2/whining (141).wav을(를) ./train4/whining/whining (141).wav로 이동했습니다.
# ./whining_2/whining (172).wav을(를) ./train4/whining/whining (172).wav로 이동했습니다.
# ./whining_2/whining (179).wav을(를) ./train4/whining/whining (179).wav로 이동했습니다.
# ./whining_2/whining (155).wav을(를) ./train4/whining/whining (155).wav로 이동했습니다.
# ./whining_2/whining (195).wav을(를) ./train4/whining/whining (195).wav로 이동했습니다.
# ./whining_2/whining (239).wav을(를) ./train4/whining/whining (239).wav로 이동했습니다.
# ./whining_2/whining (5).wav을(를) ./train4/whining/whining (5).wav로 이동했습니다.
# ./whining_2/whining (318).wav을(를) ./train4/whining/whining (318).wav로 이동했습니다.
# ./whining_2/whining (171).wav을(를) ./train4/whining/whining (171).wav로 이동했습니다.
# ./whining_2/whining (403).wav을(를) ./train4/whining/whining (403).wav로 이동했습니다.
# ./whining_2/whining (82).wav을(를) ./train4/whining/whining (82).wav로 이동했습니다.
# ./whining_2/whining (321).wav을(를) ./train4/whining/whining (321).wav로 이동했습니다.
# ./whining_2/whining (354).wav을(를) ./train4/whining/whining (354).wav로 이동했습니다.
# ./whining_2/whining (97).wav을(를) ./train4/whining/whining (97).wav로 이동했습니다.
# ./whining_2/whining (329).wav을(를) ./train4/whining/whining (329).wav로 이동했습니다.
# ./whining_2/whining (299).wav을(를) ./train4/whining/whining (299).wav로 이동했습니다.
# ./whining_2/whining (291).wav을(를) ./train4/whining/whining (291).wav로 이동했습니다.
# ./whining_2/whining (166).wav을(를) ./train4/whining/whining (166).wav로 이동했습니다.
# ./whining_2/whining (286).wav을(를) ./train4/whining/whining (286).wav로 이동했습니다.
# ./whining_2/whining (411).wav을(를) ./train4/whining/whining (411).wav로 이동했습니다.
# ./whining_2/whining (399).wav을(를) ./train4/whining/whining (399).wav로 이동했습니다.
# ./whining_2/whining (102).wav을(를) ./train4/whining/whining (102).wav로 이동했습니다.
# ./whining_2/whining (323).wav을(를) ./train4/whining/whining (323).wav로 이동했습니다.
# ./whining_2/whining (245).wav을(를) ./train4/whining/whining (245).wav로 이동했습니다.
# ./whining_2/whining (410).wav을(를) ./train4/whining/whining (410).wav로 이동했습니다.
# ./whining_2/whining (115).wav을(를) ./train4/whining/whining (115).wav로 이동했습니다.
# ./whining_2/whining (382).wav을(를) ./train4/whining/whining (382).wav로 이동했습니다.
# ./whining_2/whining (4).wav을(를) ./train4/whining/whining (4).wav로 이동했습니다.
# ./whining_2/whining (256).wav을(를) ./train4/whining/whining (256).wav로 이동했습니다.
# ./whining_2/whining (292).wav을(를) ./train4/whining/whining (292).wav로 이동했습니다.
# ./whining_2/whining (351).wav을(를) ./train4/whining/whining (351).wav로 이동했습니다.
# ./whining_2/whining (39).wav을(를) ./train4/whining/whining (39).wav로 이동했습니다.
# ./whining_2/whining (358).wav을(를) ./train4/whining/whining (358).wav로 이동했습니다.
# ./whining_2/whining (279).wav을(를) ./train4/whining/whining (279).wav로 이동했습니다.
# ./whining_2/whining (264).wav을(를) ./train4/whining/whining (264).wav로 이동했습니다.
# ./whining_2/whining (198).wav을(를) ./train4/whining/whining (198).wav로 이동했습니다.
# ./whining_2/whining (188).wav을(를) ./train4/whining/whining (188).wav로 이동했습니다.
# ./whining_2/whining (296).wav을(를) ./train4/whining/whining (296).wav로 이동했습니다.
# ./whining_2/whining (66).wav을(를) ./train4/whining/whining (66).wav로 이동했습니다.
# ./whining_2/whining (47).wav을(를) ./train4/whining/whining (47).wav로 이동했습니다.
# ./whining_2/whining (56).wav을(를) ./train4/whining/whining (56).wav로 이동했습니다.
# ./whining_2/whining (126).wav을(를) ./train4/whining/whining (126).wav로 이동했습니다.
# ./whining_2/whining (124).wav을(를) ./train4/whining/whining (124).wav로 이동했습니다.
# ./whining_2/whining (386).wav을(를) ./train4/whining/whining (386).wav로 이동했습니다.
# ./whining_2/whining (229).wav을(를) ./train4/whining/whining (229).wav로 이동했습니다.
# ./whining_2/whining (211).wav을(를) ./train4/whining/whining (211).wav로 이동했습니다.
# ./whining_2/whining (339).wav을(를) ./train4/whining/whining (339).wav로 이동했습니다.
# ./whining_2/whining (423).wav을(를) ./train4/whining/whining (423).wav로 이동했습니다.
# ./whining_2/whining (140).wav을(를) ./train4/whining/whining (140).wav로 이동했습니다.
# ./whining_2/whining (25).wav을(를) ./train4/whining/whining (25).wav로 이동했습니다.
# ./whining_2/whining (214).wav을(를) ./train4/whining/whining (214).wav로 이동했습니다.
# ./whining_2/whining (67).wav을(를) ./train4/whining/whining (67).wav로 이동했습니다.
# ./whining_2/whining (192).wav을(를) ./train4/whining/whining (192).wav로 이동했습니다.
# ./whining_2/whining (393).wav을(를) ./train4/whining/whining (393).wav로 이동했습니다.
# ./whining_2/whining (41).wav을(를) ./train4/whining/whining (41).wav로 이동했습니다.
# ./whining_2/whining (53).wav을(를) ./train4/whining/whining (53).wav로 이동했습니다.
# ./whining_2/whining (29).wav을(를) ./train4/whining/whining (29).wav로 이동했습니다.
# ./whining_2/whining (352).wav을(를) ./train4/whining/whining (352).wav로 이동했습니다.
# ./whining_2/whining (232).wav을(를) ./train4/whining/whining (232).wav로 이동했습니다.
# ./whining_2/whining (420).wav을(를) ./train4/whining/whining (420).wav로 이동했습니다.
# ./whining_2/whining (303).wav을(를) ./train4/whining/whining (303).wav로 이동했습니다.
# ./whining_2/whining (397).wav을(를) ./train4/whining/whining (397).wav로 이동했습니다.
# ./whining_2/whining (215).wav을(를) ./train4/whining/whining (215).wav로 이동했습니다.
# ./whining_2/whining (14).wav을(를) ./train4/whining/whining (14).wav로 이동했습니다.
# ./whining_2/whining (104).wav을(를) ./train4/whining/whining (104).wav로 이동했습니다.
# ./whining_2/whining (312).wav을(를) ./train4/whining/whining (312).wav로 이동했습니다.
# ./whining_2/whining (1).wav을(를) ./train4/whining/whining (1).wav로 이동했습니다.
# ./whining_2/whining (252).wav을(를) ./train4/whining/whining (252).wav로 이동했습니다.
# ./whining_2/whining (127).wav을(를) ./train4/whining/whining (127).wav로 이동했습니다.
# ./whining_2/whining (183).wav을(를) ./train4/whining/whining (183).wav로 이동했습니다.
# ./whining_2/whining (366).wav을(를) ./train4/whining/whining (366).wav로 이동했습니다.
# ./whining_2/whining (204).wav을(를) ./train4/whining/whining (204).wav로 이동했습니다.
# ./whining_2/whining (59).wav을(를) ./train4/whining/whining (59).wav로 이동했습니다.
# ./whining_2/whining (362).wav을(를) ./train4/whining/whining (362).wav로 이동했습니다.
# ./whining_2/whining (283).wav을(를) ./train4/whining/whining (283).wav로 이동했습니다.
# ./whining_2/whining (236).wav을(를) ./train4/whining/whining (236).wav로 이동했습니다.
# ./whining_2/whining (213).wav을(를) ./train4/whining/whining (213).wav로 이동했습니다.
# ./whining_2/whining (217).wav을(를) ./train4/whining/whining (217).wav로 이동했습니다.
# ./whining_2/whining (363).wav을(를) ./train4/whining/whining (363).wav로 이동했습니다.
# ./whining_2/whining (301).wav을(를) ./train4/whining/whining (301).wav로 이동했습니다.
# ./whining_2/whining (369).wav을(를) ./train4/whining/whining (369).wav로 이동했습니다.
# ./whining_2/whining (184).wav을(를) ./train4/whining/whining (184).wav로 이동했습니다.
# ./whining_2/whining (189).wav을(를) ./train4/whining/whining (189).wav로 이동했습니다.
# ./whining_2/whining (277).wav을(를) ./train4/whining/whining (277).wav로 이동했습니다.
# ./whining_2/whining (119).wav을(를) ./train4/whining/whining (119).wav로 이동했습니다.
# ./whining_2/whining (80).wav을(를) ./train4/whining/whining (80).wav로 이동했습니다.
# ./whining_2/whining (113).wav을(를) ./train4/whining/whining (113).wav로 이동했습니다.
# ./whining_2/whining (300).wav을(를) ./train4/whining/whining (300).wav로 이동했습니다.
# ./whining_2/whining (120).wav을(를) ./train4/whining/whining (120).wav로 이동했습니다.
# ./whining_2/whining (28).wav을(를) ./train4/whining/whining (28).wav로 이동했습니다.
# ./whining_2/whining (63).wav을(를) ./train4/whining/whining (63).wav로 이동했습니다.
# ./whining_2/whining (388).wav을(를) ./train4/whining/whining (388).wav로 이동했습니다.
# ./whining_2/whining (357).wav을(를) ./train4/whining/whining (357).wav로 이동했습니다.
# ./whining_2/whining (160).wav을(를) ./train4/whining/whining (160).wav로 이동했습니다.
# ./whining_2/whining (375).wav을(를) ./train4/whining/whining (375).wav로 이동했습니다.
# ./whining_2/whining (205).wav을(를) ./train4/whining/whining (205).wav로 이동했습니다.
# ./whining_2/whining (42).wav을(를) ./train4/whining/whining (42).wav로 이동했습니다.
# ./whining_2/whining (402).wav을(를) ./train4/whining/whining (402).wav로 이동했습니다.
# ./whining_2/whining (177).wav을(를) ./train4/whining/whining (177).wav로 이동했습니다.
# ./whining_2/whining (248).wav을(를) ./train4/whining/whining (248).wav로 이동했습니다.
# ./whining_2/whining (384).wav을(를) ./train4/whining/whining (384).wav로 이동했습니다.
# ./whining_2/whining (74).wav을(를) ./train4/whining/whining (74).wav로 이동했습니다.
# ./whining_2/whining (174).wav을(를) ./train4/whining/whining (174).wav로 이동했습니다.
# ./whining_2/whining (164).wav을(를) ./train4/whining/whining (164).wav로 이동했습니다.
# ./whining_2/whining (240).wav을(를) ./train4/whining/whining (240).wav로 이동했습니다.
# ./whining_2/whining (19).wav을(를) ./train4/whining/whining (19).wav로 이동했습니다.
# ./whining_2/whining (163).wav을(를) ./train4/whining/whining (163).wav로 이동했습니다.
# ./whining_2/whining (238).wav을(를) ./train4/whining/whining (238).wav로 이동했습니다.
# ./whining_2/whining (430).wav을(를) ./train4/whining/whining (430).wav로 이동했습니다.
# ./whining_2/whining (313).wav을(를) ./train4/whining/whining (313).wav로 이동했습니다.
# ./whining_2/whining (75).wav을(를) ./train4/whining/whining (75).wav로 이동했습니다.
# ./whining_2/whining (135).wav을(를) ./train4/whining/whining (135).wav로 이동했습니다.
# ./whining_2/whining (169).wav을(를) ./train4/whining/whining (169).wav로 이동했습니다.
# ./whining_2/whining (71).wav을(를) ./train4/whining/whining (71).wav로 이동했습니다.
# ./whining_2/whining (89).wav을(를) ./train4/whining/whining (89).wav로 이동했습니다.
# ./whining_2/whining (145).wav을(를) ./train4/whining/whining (145).wav로 이동했습니다.
# ./whining_2/whining (373).wav을(를) ./train4/whining/whining (373).wav로 이동했습니다.
# ./whining_2/whining (409).wav을(를) ./train4/whining/whining (409).wav로 이동했습니다.
# ./whining_2/whining (148).wav을(를) ./train4/whining/whining (148).wav로 이동했습니다.
# ./whining_2/whining (151).wav을(를) ./train4/whining/whining (151).wav로 이동했습니다.
# ./whining_2/whining (161).wav을(를) ./train4/whining/whining (161).wav로 이동했습니다.
# ./whining_2/whining (65).wav을(를) ./train4/whining/whining (65).wav로 이동했습니다.
# ./whining_2/whining (130).wav을(를) ./train4/whining/whining (130).wav로 이동했습니다.
# ./whining_2/whining (33).wav을(를) ./train4/whining/whining (33).wav로 이동했습니다.
# ./whining_2/whining (360).wav을(를) ./train4/whining/whining (360).wav로 이동했습니다.
# ./whining_2/whining (307).wav을(를) ./train4/whining/whining (307).wav로 이동했습니다.
# ./whining_2/whining (77).wav을(를) ./train4/whining/whining (77).wav로 이동했습니다.
# ./whining_2/whining (182).wav을(를) ./train4/whining/whining (182).wav로 이동했습니다.
# ./whining_2/whining (359).wav을(를) ./train4/whining/whining (359).wav로 이동했습니다.
# ./whining_2/whining (187).wav을(를) ./train4/whining/whining (187).wav로 이동했습니다.
# ./whining_2/whining (35).wav을(를) ./train4/whining/whining (35).wav로 이동했습니다.
# ./whining_2/whining (376).wav을(를) ./train4/whining/whining (376).wav로 이동했습니다.
# ./whining_2/whining (44).wav을(를) ./train4/whining/whining (44).wav로 이동했습니다.
# ./whining_2/whining (146).wav을(를) ./train4/whining/whining (146).wav로 이동했습니다.
# ./whining_2/whining (12).wav을(를) ./train4/whining/whining (12).wav로 이동했습니다.
# ./whining_2/whining (261).wav을(를) ./train4/whining/whining (261).wav로 이동했습니다.
# ./whining_2/whining (147).wav을(를) ./train4/whining/whining (147).wav로 이동했습니다.
# ./whining_2/whining (308).wav을(를) ./train4/whining/whining (308).wav로 이동했습니다.
# ./whining_2/whining (100).wav을(를) ./train4/whining/whining (100).wav로 이동했습니다.
# ./whining_2/whining (68).wav을(를) ./train4/whining/whining (68).wav로 이동했습니다.
# ./whining_2/whining (27).wav을(를) ./train4/whining/whining (27).wav로 이동했습니다.
# ./whining_2/whining (383).wav을(를) ./train4/whining/whining (383).wav로 이동했습니다.
# ./whining_2/whining (61).wav을(를) ./train4/whining/whining (61).wav로 이동했습니다.
# ./whining_2/whining (87).wav을(를) ./train4/whining/whining (87).wav로 이동했습니다.
# ./whining_2/whining (247).wav을(를) ./train4/whining/whining (247).wav로 이동했습니다.
# ./whining_2/whining (340).wav을(를) ./train4/whining/whining (340).wav로 이동했습니다.
# ./whining_2/whining (392).wav을(를) ./train4/whining/whining (392).wav로 이동했습니다.
# ./whining_2/whining (315).wav을(를) ./train4/whining/whining (315).wav로 이동했습니다.
# ./whining_2/whining (415).wav을(를) ./train4/whining/whining (415).wav로 이동했습니다.
# ./whining_2/whining (99).wav을(를) ./train4/whining/whining (99).wav로 이동했습니다.
# ./whining_2/whining (338).wav을(를) ./train4/whining/whining (338).wav로 이동했습니다.
# ./whining_2/whining (7).wav을(를) ./train4/whining/whining (7).wav로 이동했습니다.
# ./whining_2/whining (364).wav을(를) ./train4/whining/whining (364).wav로 이동했습니다.
# ./whining_2/whining (394).wav을(를) ./train4/whining/whining (394).wav로 이동했습니다.
# ./whining_2/whining (76).wav을(를) ./train4/whining/whining (76).wav로 이동했습니다.
# ./whining_2/whining (109).wav을(를) ./train4/whining/whining (109).wav로 이동했습니다.
# ./whining_2/whining (380).wav을(를) ./train4/whining/whining (380).wav로 이동했습니다.
# ./whining_2/whining (196).wav을(를) ./train4/whining/whining (196).wav로 이동했습니다.
# ./whining_2/whining (132).wav을(를) ./train4/whining/whining (132).wav로 이동했습니다.
# ./whining_2/whining (36).wav을(를) ./train4/whining/whining (36).wav로 이동했습니다.
# ./whining_2/whining (259).wav을(를) ./train4/whining/whining (259).wav로 이동했습니다.
# ./whining_2/whining (20).wav을(를) ./train4/whining/whining (20).wav로 이동했습니다.
# ./whining_2/whining (206).wav을(를) ./train4/whining/whining (206).wav로 이동했습니다.
# ./whining_2/whining (332).wav을(를) ./train4/whining/whining (332).wav로 이동했습니다.
# ./whining_2/whining (32).wav을(를) ./train4/whining/whining (32).wav로 이동했습니다.
# ./whining_2/whining (81).wav을(를) ./train4/whining/whining (81).wav로 이동했습니다.
# ./whining_2/whining (400).wav을(를) ./train4/whining/whining (400).wav로 이동했습니다.
# ./whining_2/whining (284).wav을(를) ./train4/whining/whining (284).wav로 이동했습니다.
# ./whining_2/whining (79).wav을(를) ./train4/whining/whining (79).wav로 이동했습니다.
# ./whining_2/whining (30).wav을(를) ./train4/whining/whining (30).wav로 이동했습니다.
# ./whining_2/whining (156).wav을(를) ./train4/whining/whining (156).wav로 이동했습니다.
# ./whining_2/whining (73).wav을(를) ./train4/whining/whining (73).wav로 이동했습니다.
# ./whining_2/whining (278).wav을(를) ./train4/whining/whining (278).wav로 이동했습니다.
# ./whining_2/whining (129).wav을(를) ./train4/whining/whining (129).wav로 이동했습니다.
# ./whining_2/whining (180).wav을(를) ./train4/whining/whining (180).wav로 이동했습니다.
# ./whining_2/whining (185).wav을(를) ./train4/whining/whining (185).wav로 이동했습니다.
# ./whining_2/whining (60).wav을(를) ./train4/whining/whining (60).wav로 이동했습니다.
# ./whining_2/whining (269).wav을(를) ./train4/whining/whining (269).wav로 이동했습니다.
# ./whining_2/whining (249).wav을(를) ./train4/whining/whining (249).wav로 이동했습니다.
# ./whining_2/whining (262).wav을(를) ./train4/whining/whining (262).wav로 이동했습니다.
# ./whining_2/whining (16).wav을(를) ./train4/whining/whining (16).wav로 이동했습니다.
# ./whining_2/whining (153).wav을(를) ./train4/whining/whining (153).wav로 이동했습니다.
# ./whining_2/whining (378).wav을(를) ./train4/whining/whining (378).wav로 이동했습니다.
# ./whining_2/whining (69).wav을(를) ./train4/whining/whining (69).wav로 이동했습니다.
# ./whining_2/whining (133).wav을(를) ./train4/whining/whining (133).wav로 이동했습니다.
# ./whining_2/whining (365).wav을(를) ./train4/whining/whining (365).wav로 이동했습니다.
# ./whining_2/whining (167).wav을(를) ./train4/whining/whining (167).wav로 이동했습니다.
# ./whining_2/whining (372).wav을(를) ./train4/whining/whining (372).wav로 이동했습니다.
# ./whining_2/whining (243).wav을(를) ./train4/whining/whining (243).wav로 이동했습니다.
# ./whining_2/whining (258).wav을(를) ./train4/whining/whining (258).wav로 이동했습니다.
# ./whining_2/whining (62).wav을(를) ./train4/whining/whining (62).wav로 이동했습니다.
# ./whining_2/whining (165).wav을(를) ./train4/whining/whining (165).wav로 이동했습니다.
# ./whining_2/whining (398).wav을(를) ./train4/whining/whining (398).wav로 이동했습니다.
# ./whining_2/whining (310).wav을(를) ./train4/whining/whining (310).wav로 이동했습니다.
# ./whining_2/whining (88).wav을(를) ./train4/whining/whining (88).wav로 이동했습니다.
# ./whining_2/whining (408).wav을(를) ./train4/whining/whining (408).wav로 이동했습니다.
# ./whining_2/whining (15).wav을(를) ./train4/whining/whining (15).wav로 이동했습니다.
# ./whining_2/whining (290).wav을(를) ./train4/whining/whining (290).wav로 이동했습니다.
# ./whining_2/whining (389).wav을(를) ./train4/whining/whining (389).wav로 이동했습니다.
# ./whining_2/whining (176).wav을(를) ./train4/whining/whining (176).wav로 이동했습니다.
# ./whining_2/whining (225).wav을(를) ./train4/whining/whining (225).wav로 이동했습니다.
# ./whining_2/whining (434).wav을(를) ./train4/whining/whining (434).wav로 이동했습니다.
# ./whining_2/whining (241).wav을(를) ./train4/whining/whining (241).wav로 이동했습니다.
# ./whining_2/whining (251).wav을(를) ./train4/whining/whining (251).wav로 이동했습니다.
# ./whining_2/whining (294).wav을(를) ./train4/whining/whining (294).wav로 이동했습니다.
# ./whining_2/whining (51).wav을(를) ./train4/whining/whining (51).wav로 이동했습니다.
# ./whining_2/whining (136).wav을(를) ./train4/whining/whining (136).wav로 이동했습니다.
# ./whining_2/whining (91).wav을(를) ./train4/whining/whining (91).wav로 이동했습니다.
# ./whining_2/whining (244).wav을(를) ./train4/whining/whining (244).wav로 이동했습니다.
# ./whining_2/whining (346).wav을(를) ./train4/whining/whining (346).wav로 이동했습니다.
# ./whining_2/whining (405).wav을(를) ./train4/whining/whining (405).wav로 이동했습니다.
# ./whining_2/whining (327).wav을(를) ./train4/whining/whining (327).wav로 이동했습니다.
# ./whining_2/whining (355).wav을(를) ./train4/whining/whining (355).wav로 이동했습니다.
# ./whining_2/whining (94).wav을(를) ./train4/whining/whining (94).wav로 이동했습니다.
# ./whining_2/whining (230).wav을(를) ./train4/whining/whining (230).wav로 이동했습니다.
# ./whining_2/whining (216).wav을(를) ./train4/whining/whining (216).wav로 이동했습니다.
# ./whining_2/whining (197).wav을(를) ./train4/whining/whining (197).wav로 이동했습니다.
# ./whining_2/whining (125).wav을(를) ./train4/whining/whining (125).wav로 이동했습니다.
# ./whining_2/whining (328).wav을(를) ./train4/whining/whining (328).wav로 이동했습니다.
# ./whining_2/whining (157).wav을(를) ./train4/whining/whining (157).wav로 이동했습니다.
# ./whining_2/whining (281).wav을(를) ./train4/whining/whining (281).wav로 이동했습니다.
# ./whining_2/whining (101).wav을(를) ./train4/whining/whining (101).wav로 이동했습니다.
# ./whining_2/whining (199).wav을(를) ./train4/whining/whining (199).wav로 이동했습니다.
# ./whining_2/whining (432).wav을(를) ./train4/whining/whining (432).wav로 이동했습니다.
# ./whining_2/whining (212).wav을(를) ./train4/whining/whining (212).wav로 이동했습니다.
# ./whining_2/whining (134).wav을(를) ./train4/whining/whining (134).wav로 이동했습니다.
# ./whining_2/whining (361).wav을(를) ./train4/whining/whining (361).wav로 이동했습니다.
# ./whining_2/whining (268).wav을(를) ./train4/whining/whining (268).wav로 이동했습니다.
# ./whining_2/whining (367).wav을(를) ./train4/whining/whining (367).wav로 이동했습니다.
# ./whining_2/whining (304).wav을(를) ./train4/whining/whining (304).wav로 이동했습니다.
# ./whining_2/whining (191).wav을(를) ./train4/whining/whining (191).wav로 이동했습니다.
# ./whining_2/whining (333).wav을(를) ./train4/whining/whining (333).wav로 이동했습니다.
# ./whining_2/whining (46).wav을(를) ./train4/whining/whining (46).wav로 이동했습니다.
# ./whining_2/whining (260).wav을(를) ./train4/whining/whining (260).wav로 이동했습니다.
# ./whining_2/whining (226).wav을(를) ./train4/whining/whining (226).wav로 이동했습니다.
# ./whining_2/whining (227).wav을(를) ./train4/whining/whining (227).wav로 이동했습니다.
# ./whining_2/whining (92).wav을(를) ./train4/whining/whining (92).wav로 이동했습니다.
# ./whining_2/whining (122).wav을(를) ./train4/whining/whining (122).wav로 이동했습니다.
# ./whining_2/whining (425).wav을(를) ./train4/whining/whining (425).wav로 이동했습니다.
# ./whining_2/whining (342).wav을(를) ./train4/whining/whining (342).wav로 이동했습니다.
# ./whining_2/whining (58).wav을(를) ./train4/whining/whining (58).wav로 이동했습니다.
# ./whining_2/whining (159).wav을(를) ./train4/whining/whining (159).wav로 이동했습니다.
# ./whining_2/whining (345).wav을(를) ./train4/whining/whining (345).wav로 이동했습니다.
# ./whining_2/whining (414).wav을(를) ./train4/whining/whining (414).wav로 이동했습니다.
# ./whining_2/whining (107).wav을(를) ./train4/whining/whining (107).wav로 이동했습니다.
# ./whining_2/whining (324).wav을(를) ./train4/whining/whining (324).wav로 이동했습니다.
# ./whining_2/whining (64).wav을(를) ./train4/whining/whining (64).wav로 이동했습니다.
# ./whining_2/whining (280).wav을(를) ./train4/whining/whining (280).wav로 이동했습니다.
# ./whining_2/whining (302).wav을(를) ./train4/whining/whining (302).wav로 이동했습니다.
# ./whining_2/whining (9).wav을(를) ./train4/whining/whining (9).wav로 이동했습니다.
# ./whining_2/whining (322).wav을(를) ./train4/whining/whining (322).wav로 이동했습니다.
# ./whining_2/whining (401).wav을(를) ./train4/whining/whining (401).wav로 이동했습니다.
# ./whining_2/whining (395).wav을(를) ./train4/whining/whining (395).wav로 이동했습니다.
# ./whining_2/whining (407).wav을(를) ./train4/whining/whining (407).wav로 이동했습니다.
# ./whining_2/whining (390).wav을(를) ./train4/whining/whining (390).wav로 이동했습니다.
# ./whining_2/whining (70).wav을(를) ./train4/whining/whining (70).wav로 이동했습니다.
# ./whining_2/whining (320).wav을(를) ./train4/whining/whining (320).wav로 이동했습니다.
# ./whining_2/whining (193).wav을(를) ./train4/whining/whining (193).wav로 이동했습니다.
# ./whining_2/whining (154).wav을(를) ./train4/whining/whining (154).wav로 이동했습니다.
# ./whining_2/whining (267).wav을(를) ./train4/whining/whining (267).wav로 이동했습니다.
# ./whining_2/whining (381).wav을(를) ./train4/whining/whining (381).wav로 이동했습니다.
# ./whining_2/whining (123).wav을(를) ./train4/whining/whining (123).wav로 이동했습니다.
# ./whining_2/whining (3).wav을(를) ./train4/whining/whining (3).wav로 이동했습니다.
# ./whining_2/whining (385).wav을(를) ./train4/whining/whining (385).wav로 이동했습니다.
# ./whining_2/whining (121).wav을(를) ./train4/whining/whining (121).wav로 이동했습니다.
# ./whining_2/whining (287).wav을(를) ./train4/whining/whining (287).wav로 이동했습니다.
# ./whining_2/whining (21).wav을(를) ./train4/whining/whining (21).wav로 이동했습니다.
# ./whining_2/whining (10).wav을(를) ./train4/whining/whining (10).wav로 이동했습니다.
# ./whining_2/whining (143).wav을(를) ./train4/whining/whining (143).wav로 이동했습니다.
# ./whining_2/whining (6).wav을(를) ./train4/whining/whining (6).wav로 이동했습니다.
# ./whining_2/whining (200).wav을(를) ./train4/whining/whining (200).wav로 이동했습니다.
# ./whining_2/whining (90).wav을(를) ./train4/whining/whining (90).wav로 이동했습니다.
# ./whining_2/whining (181).wav을(를) ./train4/whining/whining (181).wav로 이동했습니다.
# ./whining_2/whining (186).wav을(를) ./train4/whining/whining (186).wav로 이동했습니다.
# ./whining_2/whining (334).wav을(를) ./train4/whining/whining (334).wav로 이동했습니다.
# ./whining_2/whining (8).wav을(를) ./train4/whining/whining (8).wav로 이동했습니다.
# ./whining_2/whining (190).wav을(를) ./train4/whining/whining (190).wav로 이동했습니다.
# ./whining_2/whining (419).wav을(를) ./train4/whining/whining (419).wav로 이동했습니다.
# ./whining_2/whining (254).wav을(를) ./train4/whining/whining (254).wav로 이동했습니다.
# ./whining_2/whining (110).wav을(를) ./train4/whining/whining (110).wav로 이동했습니다.
# ./whining_2/whining (255).wav을(를) ./train4/whining/whining (255).wav로 이동했습니다.
# ./whining_2/whining (168).wav을(를) ./train4/whining/whining (168).wav로 이동했습니다.
# ./whining_2/whining (371).wav을(를) ./train4/whining/whining (371).wav로 이동했습니다.
# ./whining_2/whining (347).wav을(를) ./train4/whining/whining (347).wav로 이동했습니다.
# ./whining_2/whining (108).wav을(를) ./train4/whining/whining (108).wav로 이동했습니다.
# ./whining_2/whining (433).wav을(를) ./train4/whining/whining (433).wav로 이동했습니다.
# ./whining_2/whining (343).wav을(를) ./train4/whining/whining (343).wav로 이동했습니다.
# ./whining_2/whining (421).wav을(를) ./train4/whining/whining (421).wav로 이동했습니다.
# ./whining_2/whining (325).wav을(를) ./train4/whining/whining (325).wav로 이동했습니다.
# ./whining_2/whining (253).wav을(를) ./train4/whining/whining (253).wav로 이동했습니다.
# ./whining_2/whining (263).wav을(를) ./train4/whining/whining (263).wav로 이동했습니다.
# ./whining_2/whining (128).wav을(를) ./train4/whining/whining (128).wav로 이동했습니다.
# ./whining_2/whining (152).wav을(를) ./train4/whining/whining (152).wav로 이동했습니다.
# ./whining_2/whining (93).wav을(를) ./train4/whining/whining (93).wav로 이동했습니다.
# ./whining_2/whining (274).wav을(를) ./train4/whining/whining (274).wav로 이동했습니다.
# ./whining_2/whining (418).wav을(를) ./train4/whining/whining (418).wav로 이동했습니다.
# ./whining_2/whining (330).wav을(를) ./train4/whining/whining (330).wav로 이동했습니다.
# ./whining_2/whining (218).wav을(를) ./train4/whining/whining (218).wav로 이동했습니다.
# ./whining_2/whining (209).wav을(를) ./train4/whining/whining (209).wav로 이동했습니다.
# ./whining_2/whining (2).wav을(를) ./train4/whining/whining (2).wav로 이동했습니다.
# ./whining_2/whining (412).wav을(를) ./train4/whining/whining (412).wav로 이동했습니다.
# ./whining_2/whining (45).wav을(를) ./train4/whining/whining (45).wav로 이동했습니다.
# ./whining_2/whining (422).wav을(를) ./train4/whining/whining (422).wav로 이동했습니다.
# ./whining_2/whining (142).wav을(를) ./train4/whining/whining (142).wav로 이동했습니다.
# ./whining_2/whining (105).wav을(를) ./train4/whining/whining (105).wav로 이동했습니다.
# ./whining_2/whining (49).wav을(를) ./train4/whining/whining (49).wav로 이동했습니다.
# ./whining_2/whining (18).wav을(를) ./train4/whining/whining (18).wav로 이동했습니다.
# ./whining_2/whining (331).wav을(를) ./train4/whining/whining (331).wav로 이동했습니다.
# ./whining_2/whining (295).wav을(를) ./train4/whining/whining (295).wav로 이동했습니다.
# ./whining_2/whining (387).wav을(를) ./train4/whining/whining (387).wav로 이동했습니다.
# ./whining_2/whining (178).wav을(를) ./train4/whining/whining (178).wav로 이동했습니다.
# ./whining_2/whining (348).wav을(를) ./train4/whining/whining (348).wav로 이동했습니다.
# ./whining_2/whining (175).wav을(를) ./train4/whining/whining (175).wav로 이동했습니다.
# ./whining_2/whining (85).wav을(를) ./test4/whining/whining (85).wav로 이동했습니다.
# ./whining_2/whining (242).wav을(를) ./test4/whining/whining (242).wav로 이동했습니다.
# ./whining_2/whining (424).wav을(를) ./test4/whining/whining (424).wav로 이동했습니다.
# ./whining_2/whining (223).wav을(를) ./test4/whining/whining (223).wav로 이동했습니다.
# ./whining_2/whining (52).wav을(를) ./test4/whining/whining (52).wav로 이동했습니다.
# ./whining_2/whining (311).wav을(를) ./test4/whining/whining (311).wav로 이동했습니다.
# ./whining_2/whining (48).wav을(를) ./test4/whining/whining (48).wav로 이동했습니다.
# ./whining_2/whining (353).wav을(를) ./test4/whining/whining (353).wav로 이동했습니다.
# ./whining_2/whining (404).wav을(를) ./test4/whining/whining (404).wav로 이동했습니다.
# ./whining_2/whining (293).wav을(를) ./test4/whining/whining (293).wav로 이동했습니다.
# ./whining_2/whining (271).wav을(를) ./test4/whining/whining (271).wav로 이동했습니다.
# ./whining_2/whining (137).wav을(를) ./test4/whining/whining (137).wav로 이동했습니다.
# ./whining_2/whining (341).wav을(를) ./test4/whining/whining (341).wav로 이동했습니다.
# ./whining_2/whining (17).wav을(를) ./test4/whining/whining (17).wav로 이동했습니다.
# ./whining_2/whining (235).wav을(를) ./test4/whining/whining (235).wav로 이동했습니다.
# ./whining_2/whining (78).wav을(를) ./test4/whining/whining (78).wav로 이동했습니다.
# ./whining_2/whining (194).wav을(를) ./test4/whining/whining (194).wav로 이동했습니다.
# ./whining_2/whining (237).wav을(를) ./test4/whining/whining (237).wav로 이동했습니다.
# ./whining_2/whining (224).wav을(를) ./test4/whining/whining (224).wav로 이동했습니다.
# ./whining_2/whining (344).wav을(를) ./test4/whining/whining (344).wav로 이동했습니다.
# ./whining_2/whining (431).wav을(를) ./test4/whining/whining (431).wav로 이동했습니다.
# ./whining_2/whining (55).wav을(를) ./test4/whining/whining (55).wav로 이동했습니다.
# ./whining_2/whining (106).wav을(를) ./test4/whining/whining (106).wav로 이동했습니다.
# ./whining_2/whining (96).wav을(를) ./test4/whining/whining (96).wav로 이동했습니다.
# ./whining_2/whining (50).wav을(를) ./test4/whining/whining (50).wav로 이동했습니다.
# ./whining_2/whining (265).wav을(를) ./test4/whining/whining (265).wav로 이동했습니다.
# ./whining_2/whining (417).wav을(를) ./test4/whining/whining (417).wav로 이동했습니다.
# ./whining_2/whining (306).wav을(를) ./test4/whining/whining (306).wav로 이동했습니다.
# ./whining_2/whining (297).wav을(를) ./test4/whining/whining (297).wav로 이동했습니다.
# ./whining_2/whining (203).wav을(를) ./test4/whining/whining (203).wav로 이동했습니다.
# ./whining_2/whining (428).wav을(를) ./test4/whining/whining (428).wav로 이동했습니다.
# ./whining_2/whining (257).wav을(를) ./test4/whining/whining (257).wav로 이동했습니다.
# ./whining_2/whining (83).wav을(를) ./test4/whining/whining (83).wav로 이동했습니다.
# ./whining_2/whining (103).wav을(를) ./test4/whining/whining (103).wav로 이동했습니다.
# ./whining_2/whining (144).wav을(를) ./test4/whining/whining (144).wav로 이동했습니다.
# ./whining_2/whining (413).wav을(를) ./test4/whining/whining (413).wav로 이동했습니다.
# ./whining_2/whining (266).wav을(를) ./test4/whining/whining (266).wav로 이동했습니다.
# ./whining_2/whining (317).wav을(를) ./test4/whining/whining (317).wav로 이동했습니다.
# ./whining_2/whining (112).wav을(를) ./test4/whining/whining (112).wav로 이동했습니다.
# ./whining_2/whining (396).wav을(를) ./test4/whining/whining (396).wav로 이동했습니다.
# ./whining_2/whining (234).wav을(를) ./test4/whining/whining (234).wav로 이동했습니다.
# ./whining_2/whining (31).wav을(를) ./test4/whining/whining (31).wav로 이동했습니다.
# ./whining_2/whining (370).wav을(를) ./test4/whining/whining (370).wav로 이동했습니다.
# ./whining_2/whining (233).wav을(를) ./test4/whining/whining (233).wav로 이동했습니다.
# ./whining_2/whining (23).wav을(를) ./test4/whining/whining (23).wav로 이동했습니다.
# ./whining_2/whining (22).wav을(를) ./test4/whining/whining (22).wav로 이동했습니다.
# ./whining_2/whining (201).wav을(를) ./test4/whining/whining (201).wav로 이동했습니다.
# ./whining_2/whining (337).wav을(를) ./test4/whining/whining (337).wav로 이동했습니다.
# ./whining_2/whining (377).wav을(를) ./test4/whining/whining (377).wav로 이동했습니다.
# ./whining_2/whining (173).wav을(를) ./test4/whining/whining (173).wav로 이동했습니다.
# ./whining_2/whining (54).wav을(를) ./test4/whining/whining (54).wav로 이동했습니다.
# ./whining_2/whining (13).wav을(를) ./test4/whining/whining (13).wav로 이동했습니다.
# ./whining_2/whining (285).wav을(를) ./test4/whining/whining (285).wav로 이동했습니다.
# ./whining_2/whining (219).wav을(를) ./test4/whining/whining (219).wav로 이동했습니다.
# ./whining_2/whining (305).wav을(를) ./test4/whining/whining (305).wav로 이동했습니다.
# ./whining_2/whining (40).wav을(를) ./test4/whining/whining (40).wav로 이동했습니다.
# ./whining_2/whining (276).wav을(를) ./test4/whining/whining (276).wav로 이동했습니다.
# ./whining_2/whining (95).wav을(를) ./test4/whining/whining (95).wav로 이동했습니다.
# ./whining_2/whining (221).wav을(를) ./test4/whining/whining (221).wav로 이동했습니다.
# ./whining_2/whining (86).wav을(를) ./test4/whining/whining (86).wav로 이동했습니다.
# ./whining_2/whining (84).wav을(를) ./test4/whining/whining (84).wav로 이동했습니다.
# ./whining_2/whining (288).wav을(를) ./test4/whining/whining (288).wav로 이동했습니다.
# ./whining_2/whining (427).wav을(를) ./test4/whining/whining (427).wav로 이동했습니다.
# ./whining_2/whining (220).wav을(를) ./test4/whining/whining (220).wav로 이동했습니다.
# ./whining_2/whining (298).wav을(를) ./test4/whining/whining (298).wav로 이동했습니다.
# ./whining_2/whining (118).wav을(를) ./test4/whining/whining (118).wav로 이동했습니다.
# ./whining_2/whining (391).wav을(를) ./test4/whining/whining (391).wav로 이동했습니다.
# ./whining_2/whining (349).wav을(를) ./test4/whining/whining (349).wav로 이동했습니다.
# ./whining_2/whining (170).wav을(를) ./test4/whining/whining (170).wav로 이동했습니다.
# ./whining_2/whining (228).wav을(를) ./test4/whining/whining (228).wav로 이동했습니다.
# ./whining_2/whining (149).wav을(를) ./test4/whining/whining (149).wav로 이동했습니다.
# ./whining_2/whining (117).wav을(를) ./test4/whining/whining (117).wav로 이동했습니다.
# ./whining_2/whining (139).wav을(를) ./test4/whining/whining (139).wav로 이동했습니다.
# ./whining_2/whining (114).wav을(를) ./test4/whining/whining (114).wav로 이동했습니다.
# ./whining_2/whining (314).wav을(를) ./test4/whining/whining (314).wav로 이동했습니다.
# ./whining_2/whining (309).wav을(를) ./test4/whining/whining (309).wav로 이동했습니다.
# ./whining_2/whining (111).wav을(를) ./test4/whining/whining (111).wav로 이동했습니다.
# ./whining_2/whining (335).wav을(를) ./test4/whining/whining (335).wav로 이동했습니다.
# ./whining_2/whining (368).wav을(를) ./test4/whining/whining (368).wav로 이동했습니다.
# ./whining_2/whining (162).wav을(를) ./test4/whining/whining (162).wav로 이동했습니다.
# ./whining_2/whining (138).wav을(를) ./test4/whining/whining (138).wav로 이동했습니다.
# ./whining_2/whining (116).wav을(를) ./test4/whining/whining (116).wav로 이동했습니다.
# ./whining_2/whining (38).wav을(를) ./test4/whining/whining (38).wav로 이동했습니다.
# ./whining_2/whining (416).wav을(를) ./test4/whining/whining (416).wav로 이동했습니다.
# ./whining_2/whining (326).wav을(를) ./test4/whining/whining (326).wav로 이동했습니다.
# ./whining_2/whining (34).wav을(를) ./test4/whining/whining (34).wav로 이동했습니다.
# ./barking_2/barking (551).wav을(를) ./train4/barking/barking (551).wav로 이동했습니다.
# ./barking_2/barking (1017).wav을(를) ./train4/barking/barking (1017).wav로 이동했습니다.
# ./barking_2/barking (585).wav을(를) ./train4/barking/barking (585).wav로 이동했습니다.
# ./barking_2/barking (59).wav을(를) ./train4/barking/barking (59).wav로 이동했습니다.
# ./barking_2/barking (97).wav을(를) ./train4/barking/barking (97).wav로 이동했습니다.
# ./barking_2/barking (859).wav을(를) ./train4/barking/barking (859).wav로 이동했습니다.
# ./barking_2/barking (213).wav을(를) ./train4/barking/barking (213).wav로 이동했습니다.
# ./barking_2/barking (20).wav을(를) ./train4/barking/barking (20).wav로 이동했습니다.
# ./barking_2/barking (117).wav을(를) ./train4/barking/barking (117).wav로 이동했습니다.
# ./barking_2/barking (974).wav을(를) ./train4/barking/barking (974).wav로 이동했습니다.
# ./barking_2/barking (457).wav을(를) ./train4/barking/barking (457).wav로 이동했습니다.
# ./barking_2/barking (606).wav을(를) ./train4/barking/barking (606).wav로 이동했습니다.
# ./barking_2/barking (232).wav을(를) ./train4/barking/barking (232).wav로 이동했습니다.
# ./barking_2/barking (699).wav을(를) ./train4/barking/barking (699).wav로 이동했습니다.
# ./barking_2/barking (277).wav을(를) ./train4/barking/barking (277).wav로 이동했습니다.
# ./barking_2/barking (116).wav을(를) ./train4/barking/barking (116).wav로 이동했습니다.
# ./barking_2/barking (804).wav을(를) ./train4/barking/barking (804).wav로 이동했습니다.
# ./barking_2/barking (952).wav을(를) ./train4/barking/barking (952).wav로 이동했습니다.
# ./barking_2/barking (1098).wav을(를) ./train4/barking/barking (1098).wav로 이동했습니다.
# ./barking_2/barking (296).wav을(를) ./train4/barking/barking (296).wav로 이동했습니다.
# ./barking_2/barking (28).wav을(를) ./train4/barking/barking (28).wav로 이동했습니다.
# ./barking_2/barking (341).wav을(를) ./train4/barking/barking (341).wav로 이동했습니다.
# ./barking_2/barking (809).wav을(를) ./train4/barking/barking (809).wav로 이동했습니다.
# ./barking_2/barking (921).wav을(를) ./train4/barking/barking (921).wav로 이동했습니다.
# ./barking_2/barking (444).wav을(를) ./train4/barking/barking (444).wav로 이동했습니다.
# ./barking_2/barking (448).wav을(를) ./train4/barking/barking (448).wav로 이동했습니다.
# ./barking_2/barking (414).wav을(를) ./train4/barking/barking (414).wav로 이동했습니다.
# ./barking_2/barking (78).wav을(를) ./train4/barking/barking (78).wav로 이동했습니다.
# ./barking_2/barking (862).wav을(를) ./train4/barking/barking (862).wav로 이동했습니다.
# ./barking_2/barking (454).wav을(를) ./train4/barking/barking (454).wav로 이동했습니다.
# ./barking_2/barking (55).wav을(를) ./train4/barking/barking (55).wav로 이동했습니다.
# ./barking_2/barking (105).wav을(를) ./train4/barking/barking (105).wav로 이동했습니다.
# ./barking_2/barking (983).wav을(를) ./train4/barking/barking (983).wav로 이동했습니다.
# ./barking_2/barking (633).wav을(를) ./train4/barking/barking (633).wav로 이동했습니다.
# ./barking_2/barking (62).wav을(를) ./train4/barking/barking (62).wav로 이동했습니다.
# ./barking_2/barking (172).wav을(를) ./train4/barking/barking (172).wav로 이동했습니다.
# ./barking_2/barking (717).wav을(를) ./train4/barking/barking (717).wav로 이동했습니다.
# ./barking_2/barking (415).wav을(를) ./train4/barking/barking (415).wav로 이동했습니다.
# ./barking_2/barking (294).wav을(를) ./train4/barking/barking (294).wav로 이동했습니다.
# ./barking_2/barking (366).wav을(를) ./train4/barking/barking (366).wav로 이동했습니다.
# ./barking_2/barking (897).wav을(를) ./train4/barking/barking (897).wav로 이동했습니다.
# ./barking_2/barking (534).wav을(를) ./train4/barking/barking (534).wav로 이동했습니다.
# ./barking_2/barking (479).wav을(를) ./train4/barking/barking (479).wav로 이동했습니다.
# ./barking_2/barking (514).wav을(를) ./train4/barking/barking (514).wav로 이동했습니다.
# ./barking_2/barking (22).wav을(를) ./train4/barking/barking (22).wav로 이동했습니다.
# ./barking_2/barking (265).wav을(를) ./train4/barking/barking (265).wav로 이동했습니다.
# ./barking_2/barking (527).wav을(를) ./train4/barking/barking (527).wav로 이동했습니다.
# ./barking_2/barking (885).wav을(를) ./train4/barking/barking (885).wav로 이동했습니다.
# ./barking_2/barking (923).wav을(를) ./train4/barking/barking (923).wav로 이동했습니다.
# ./barking_2/barking (583).wav을(를) ./train4/barking/barking (583).wav로 이동했습니다.
# ./barking_2/barking (267).wav을(를) ./train4/barking/barking (267).wav로 이동했습니다.
# ./barking_2/barking (292).wav을(를) ./train4/barking/barking (292).wav로 이동했습니다.
# ./barking_2/barking (982).wav을(를) ./train4/barking/barking (982).wav로 이동했습니다.
# ./barking_2/barking (820).wav을(를) ./train4/barking/barking (820).wav로 이동했습니다.
# ./barking_2/barking (164).wav을(를) ./train4/barking/barking (164).wav로 이동했습니다.
# ./barking_2/barking (729).wav을(를) ./train4/barking/barking (729).wav로 이동했습니다.
# ./barking_2/barking (878).wav을(를) ./train4/barking/barking (878).wav로 이동했습니다.
# ./barking_2/barking (63).wav을(를) ./train4/barking/barking (63).wav로 이동했습니다.
# ./barking_2/barking (875).wav을(를) ./train4/barking/barking (875).wav로 이동했습니다.
# ./barking_2/barking (136).wav을(를) ./train4/barking/barking (136).wav로 이동했습니다.
# ./barking_2/barking (56).wav을(를) ./train4/barking/barking (56).wav로 이동했습니다.
# ./barking_2/barking (443).wav을(를) ./train4/barking/barking (443).wav로 이동했습니다.
# ./barking_2/barking (814).wav을(를) ./train4/barking/barking (814).wav로 이동했습니다.
# ./barking_2/barking (573).wav을(를) ./train4/barking/barking (573).wav로 이동했습니다.
# ./barking_2/barking (21).wav을(를) ./train4/barking/barking (21).wav로 이동했습니다.
# ./barking_2/barking (972).wav을(를) ./train4/barking/barking (972).wav로 이동했습니다.
# ./barking_2/barking (159).wav을(를) ./train4/barking/barking (159).wav로 이동했습니다.
# ./barking_2/barking (206).wav을(를) ./train4/barking/barking (206).wav로 이동했습니다.
# ./barking_2/barking (794).wav을(를) ./train4/barking/barking (794).wav로 이동했습니다.
# ./barking_2/barking (189).wav을(를) ./train4/barking/barking (189).wav로 이동했습니다.
# ./barking_2/barking (865).wav을(를) ./train4/barking/barking (865).wav로 이동했습니다.
# ./barking_2/barking (1116).wav을(를) ./train4/barking/barking (1116).wav로 이동했습니다.
# ./barking_2/barking (590).wav을(를) ./train4/barking/barking (590).wav로 이동했습니다.
# ./barking_2/barking (682).wav을(를) ./train4/barking/barking (682).wav로 이동했습니다.
# ./barking_2/barking (460).wav을(를) ./train4/barking/barking (460).wav로 이동했습니다.
# ./barking_2/barking (799).wav을(를) ./train4/barking/barking (799).wav로 이동했습니다.
# ./barking_2/barking (892).wav을(를) ./train4/barking/barking (892).wav로 이동했습니다.
# ./barking_2/barking (758).wav을(를) ./train4/barking/barking (758).wav로 이동했습니다.
# ./barking_2/barking (734).wav을(를) ./train4/barking/barking (734).wav로 이동했습니다.
# ./barking_2/barking (155).wav을(를) ./train4/barking/barking (155).wav로 이동했습니다.
# ./barking_2/barking (538).wav을(를) ./train4/barking/barking (538).wav로 이동했습니다.
# ./barking_2/barking (506).wav을(를) ./train4/barking/barking (506).wav로 이동했습니다.
# ./barking_2/barking (656).wav을(를) ./train4/barking/barking (656).wav로 이동했습니다.
# ./barking_2/barking (247).wav을(를) ./train4/barking/barking (247).wav로 이동했습니다.
# ./barking_2/barking (788).wav을(를) ./train4/barking/barking (788).wav로 이동했습니다.
# ./barking_2/barking (782).wav을(를) ./train4/barking/barking (782).wav로 이동했습니다.
# ./barking_2/barking (658).wav을(를) ./train4/barking/barking (658).wav로 이동했습니다.
# ./barking_2/barking (779).wav을(를) ./train4/barking/barking (779).wav로 이동했습니다.
# ./barking_2/barking (710).wav을(를) ./train4/barking/barking (710).wav로 이동했습니다.
# ./barking_2/barking (808).wav을(를) ./train4/barking/barking (808).wav로 이동했습니다.
# ./barking_2/barking (373).wav을(를) ./train4/barking/barking (373).wav로 이동했습니다.
# ./barking_2/barking (6).wav을(를) ./train4/barking/barking (6).wav로 이동했습니다.
# ./barking_2/barking (694).wav을(를) ./train4/barking/barking (694).wav로 이동했습니다.
# ./barking_2/barking (2).wav을(를) ./train4/barking/barking (2).wav로 이동했습니다.
# ./barking_2/barking (209).wav을(를) ./train4/barking/barking (209).wav로 이동했습니다.
# ./barking_2/barking (276).wav을(를) ./train4/barking/barking (276).wav로 이동했습니다.
# ./barking_2/barking (824).wav을(를) ./train4/barking/barking (824).wav로 이동했습니다.
# ./barking_2/barking (839).wav을(를) ./train4/barking/barking (839).wav로 이동했습니다.
# ./barking_2/barking (667).wav을(를) ./train4/barking/barking (667).wav로 이동했습니다.
# ./barking_2/barking (697).wav을(를) ./train4/barking/barking (697).wav로 이동했습니다.
# ./barking_2/barking (985).wav을(를) ./train4/barking/barking (985).wav로 이동했습니다.
# ./barking_2/barking (671).wav을(를) ./train4/barking/barking (671).wav로 이동했습니다.
# ./barking_2/barking (188).wav을(를) ./train4/barking/barking (188).wav로 이동했습니다.
# ./barking_2/barking (660).wav을(를) ./train4/barking/barking (660).wav로 이동했습니다.
# ./barking_2/barking (882).wav을(를) ./train4/barking/barking (882).wav로 이동했습니다.
# ./barking_2/barking (1010).wav을(를) ./train4/barking/barking (1010).wav로 이동했습니다.
# ./barking_2/barking (411).wav을(를) ./train4/barking/barking (411).wav로 이동했습니다.
# ./barking_2/barking (328).wav을(를) ./train4/barking/barking (328).wav로 이동했습니다.
# ./barking_2/barking (876).wav을(를) ./train4/barking/barking (876).wav로 이동했습니다.
# ./barking_2/barking (305).wav을(를) ./train4/barking/barking (305).wav로 이동했습니다.
# ./barking_2/barking (481).wav을(를) ./train4/barking/barking (481).wav로 이동했습니다.
# ./barking_2/barking (505).wav을(를) ./train4/barking/barking (505).wav로 이동했습니다.
# ./barking_2/barking (95).wav을(를) ./train4/barking/barking (95).wav로 이동했습니다.
# ./barking_2/barking (1026).wav을(를) ./train4/barking/barking (1026).wav로 이동했습니다.
# ./barking_2/barking (35).wav을(를) ./train4/barking/barking (35).wav로 이동했습니다.
# ./barking_2/barking (285).wav을(를) ./train4/barking/barking (285).wav로 이동했습니다.
# ./barking_2/barking (464).wav을(를) ./train4/barking/barking (464).wav로 이동했습니다.
# ./barking_2/barking (440).wav을(를) ./train4/barking/barking (440).wav로 이동했습니다.
# ./barking_2/barking (765).wav을(를) ./train4/barking/barking (765).wav로 이동했습니다.
# ./barking_2/barking (970).wav을(를) ./train4/barking/barking (970).wav로 이동했습니다.
# ./barking_2/barking (240).wav을(를) ./train4/barking/barking (240).wav로 이동했습니다.
# ./barking_2/barking (16).wav을(를) ./train4/barking/barking (16).wav로 이동했습니다.
# ./barking_2/barking (503).wav을(를) ./train4/barking/barking (503).wav로 이동했습니다.
# ./barking_2/barking (654).wav을(를) ./train4/barking/barking (654).wav로 이동했습니다.
# ./barking_2/barking (104).wav을(를) ./train4/barking/barking (104).wav로 이동했습니다.
# ./barking_2/barking (9).wav을(를) ./train4/barking/barking (9).wav로 이동했습니다.
# ./barking_2/barking (561).wav을(를) ./train4/barking/barking (561).wav로 이동했습니다.
# ./barking_2/barking (637).wav을(를) ./train4/barking/barking (637).wav로 이동했습니다.
# ./barking_2/barking (246).wav을(를) ./train4/barking/barking (246).wav로 이동했습니다.
# ./barking_2/barking (834).wav을(를) ./train4/barking/barking (834).wav로 이동했습니다.
# ./barking_2/barking (113).wav을(를) ./train4/barking/barking (113).wav로 이동했습니다.
# ./barking_2/barking (630).wav을(를) ./train4/barking/barking (630).wav로 이동했습니다.
# ./barking_2/barking (96).wav을(를) ./train4/barking/barking (96).wav로 이동했습니다.
# ./barking_2/barking (57).wav을(를) ./train4/barking/barking (57).wav로 이동했습니다.
# ./barking_2/barking (185).wav을(를) ./train4/barking/barking (185).wav로 이동했습니다.
# ./barking_2/barking (624).wav을(를) ./train4/barking/barking (624).wav로 이동했습니다.
# ./barking_2/barking (754).wav을(를) ./train4/barking/barking (754).wav로 이동했습니다.
# ./barking_2/barking (1105).wav을(를) ./train4/barking/barking (1105).wav로 이동했습니다.
# ./barking_2/barking (248).wav을(를) ./train4/barking/barking (248).wav로 이동했습니다.
# ./barking_2/barking (1066).wav을(를) ./train4/barking/barking (1066).wav로 이동했습니다.
# ./barking_2/barking (254).wav을(를) ./train4/barking/barking (254).wav로 이동했습니다.
# ./barking_2/barking (315).wav을(를) ./train4/barking/barking (315).wav로 이동했습니다.
# ./barking_2/barking (412).wav을(를) ./train4/barking/barking (412).wav로 이동했습니다.
# ./barking_2/barking (335).wav을(를) ./train4/barking/barking (335).wav로 이동했습니다.
# ./barking_2/barking (888).wav을(를) ./train4/barking/barking (888).wav로 이동했습니다.
# ./barking_2/barking (773).wav을(를) ./train4/barking/barking (773).wav로 이동했습니다.
# ./barking_2/barking (456).wav을(를) ./train4/barking/barking (456).wav로 이동했습니다.
# ./barking_2/barking (651).wav을(를) ./train4/barking/barking (651).wav로 이동했습니다.
# ./barking_2/barking (70).wav을(를) ./train4/barking/barking (70).wav로 이동했습니다.
# ./barking_2/barking (264).wav을(를) ./train4/barking/barking (264).wav로 이동했습니다.
# ./barking_2/barking (540).wav을(를) ./train4/barking/barking (540).wav로 이동했습니다.
# ./barking_2/barking (1107).wav을(를) ./train4/barking/barking (1107).wav로 이동했습니다.
# ./barking_2/barking (278).wav을(를) ./train4/barking/barking (278).wav로 이동했습니다.
# ./barking_2/barking (168).wav을(를) ./train4/barking/barking (168).wav로 이동했습니다.
# ./barking_2/barking (458).wav을(를) ./train4/barking/barking (458).wav로 이동했습니다.
# ./barking_2/barking (894).wav을(를) ./train4/barking/barking (894).wav로 이동했습니다.
# ./barking_2/barking (381).wav을(를) ./train4/barking/barking (381).wav로 이동했습니다.
# ./barking_2/barking (123).wav을(를) ./train4/barking/barking (123).wav로 이동했습니다.
# ./barking_2/barking (948).wav을(를) ./train4/barking/barking (948).wav로 이동했습니다.
# ./barking_2/barking (428).wav을(를) ./train4/barking/barking (428).wav로 이동했습니다.
# ./barking_2/barking (297).wav을(를) ./train4/barking/barking (297).wav로 이동했습니다.
# ./barking_2/barking (1077).wav을(를) ./train4/barking/barking (1077).wav로 이동했습니다.
# ./barking_2/barking (32).wav을(를) ./train4/barking/barking (32).wav로 이동했습니다.
# ./barking_2/barking (313).wav을(를) ./train4/barking/barking (313).wav로 이동했습니다.
# ./barking_2/barking (1087).wav을(를) ./train4/barking/barking (1087).wav로 이동했습니다.
# ./barking_2/barking (727).wav을(를) ./train4/barking/barking (727).wav로 이동했습니다.
# ./barking_2/barking (826).wav을(를) ./train4/barking/barking (826).wav로 이동했습니다.
# ./barking_2/barking (725).wav을(를) ./train4/barking/barking (725).wav로 이동했습니다.
# ./barking_2/barking (23).wav을(를) ./train4/barking/barking (23).wav로 이동했습니다.
# ./barking_2/barking (746).wav을(를) ./train4/barking/barking (746).wav로 이동했습니다.
# ./barking_2/barking (618).wav을(를) ./train4/barking/barking (618).wav로 이동했습니다.
# ./barking_2/barking (1032).wav을(를) ./train4/barking/barking (1032).wav로 이동했습니다.
# ./barking_2/barking (324).wav을(를) ./train4/barking/barking (324).wav로 이동했습니다.
# ./barking_2/barking (252).wav을(를) ./train4/barking/barking (252).wav로 이동했습니다.
# ./barking_2/barking (963).wav을(를) ./train4/barking/barking (963).wav로 이동했습니다.
# ./barking_2/barking (962).wav을(를) ./train4/barking/barking (962).wav로 이동했습니다.
# ./barking_2/barking (355).wav을(를) ./train4/barking/barking (355).wav로 이동했습니다.
# ./barking_2/barking (776).wav을(를) ./train4/barking/barking (776).wav로 이동했습니다.
# ./barking_2/barking (781).wav을(를) ./train4/barking/barking (781).wav로 이동했습니다.
# ./barking_2/barking (539).wav을(를) ./train4/barking/barking (539).wav로 이동했습니다.
# ./barking_2/barking (77).wav을(를) ./train4/barking/barking (77).wav로 이동했습니다.
# ./barking_2/barking (611).wav을(를) ./train4/barking/barking (611).wav로 이동했습니다.
# ./barking_2/barking (218).wav을(를) ./train4/barking/barking (218).wav로 이동했습니다.
# ./barking_2/barking (340).wav을(를) ./train4/barking/barking (340).wav로 이동했습니다.
# ./barking_2/barking (785).wav을(를) ./train4/barking/barking (785).wav로 이동했습니다.
# ...
# ./barking_2/barking (1039).wav을(를) ./test4/barking/barking (1039).wav로 이동했습니다.
# ./barking_2/barking (316).wav을(를) ./test4/barking/barking (316).wav로 이동했습니다.
# ./barking_2/barking (993).wav을(를) ./test4/barking/barking (993).wav로 이동했습니다.
# ./barking_2/barking (909).wav을(를) ./test4/barking/barking (909).wav로 이동했습니다.
# ./barking_2/barking (638).wav을(를) ./test4/barking/barking (638).wav로 이동했습니다.
# ./barking_2/barking (621).wav을(를) ./test4/barking/barking (621).wav로 이동했습니다.
# ./barking_2/barking (83).wav을(를) ./test4/barking/barking (83).wav로 이동했습니다.
# ./barking_2/barking (212).wav을(를) ./test4/barking/barking (212).wav로 이동했습니다.
# ./barking_2/barking (622).wav을(를) ./test4/barking/barking (622).wav로 이동했습니다.
# ./barking_2/barking (508).wav을(를) ./test4/barking/barking (508).wav로 이동했습니다.
# ./barking_2/barking (623).wav을(를) ./test4/barking/barking (623).wav로 이동했습니다.
# ./barking_2/barking (102).wav을(를) ./test4/barking/barking (102).wav로 이동했습니다.
# ./barking_2/barking (891).wav을(를) ./test4/barking/barking (891).wav로 이동했습니다.
# ./barking_2/barking (52).wav을(를) ./test4/barking/barking (52).wav로 이동했습니다.
# ./barking_2/barking (452).wav을(를) ./test4/barking/barking (452).wav로 이동했습니다.
# ./barking_2/barking (911).wav을(를) ./test4/barking/barking (911).wav로 이동했습니다.
# ./barking_2/barking (732).wav을(를) ./test4/barking/barking (732).wav로 이동했습니다.
# ./barking_2/barking (299).wav을(를) ./test4/barking/barking (299).wav로 이동했습니다.
# ./barking_2/barking (199).wav을(를) ./test4/barking/barking (199).wav로 이동했습니다.
# ./barking_2/barking (770).wav을(를) ./test4/barking/barking (770).wav로 이동했습니다.
# ./barking_2/barking (841).wav을(를) ./test4/barking/barking (841).wav로 이동했습니다.
# ./barking_2/barking (994).wav을(를) ./test4/barking/barking (994).wav로 이동했습니다.
# ./barking_2/barking (713).wav을(를) ./test4/barking/barking (713).wav로 이동했습니다.
# ./barking_2/barking (569).wav을(를) ./test4/barking/barking (569).wav로 이동했습니다.
# ./barking_2/barking (845).wav을(를) ./test4/barking/barking (845).wav로 이동했습니다.
# ./barking_2/barking (631).wav을(를) ./test4/barking/barking (631).wav로 이동했습니다.
# ./barking_2/barking (384).wav을(를) ./test4/barking/barking (384).wav로 이동했습니다.
# ./barking_2/barking (465).wav을(를) ./test4/barking/barking (465).wav로 이동했습니다.
# ./barking_2/barking (279).wav을(를) ./test4/barking/barking (279).wav로 이동했습니다.
# ./barking_2/barking (171).wav을(를) ./test4/barking/barking (171).wav로 이동했습니다.
# ./barking_2/barking (435).wav을(를) ./test4/barking/barking (435).wav로 이동했습니다.
# ./barking_2/barking (625).wav을(를) ./test4/barking/barking (625).wav로 이동했습니다.
# ./barking_2/barking (635).wav을(를) ./test4/barking/barking (635).wav로 이동했습니다.
# ./barking_2/barking (368).wav을(를) ./test4/barking/barking (368).wav로 이동했습니다.
# ./barking_2/barking (1112).wav을(를) ./test4/barking/barking (1112).wav로 이동했습니다.
# ./barking_2/barking (491).wav을(를) ./test4/barking/barking (491).wav로 이동했습니다.
# ./barking_2/barking (407).wav을(를) ./test4/barking/barking (407).wav로 이동했습니다.
# ./barking_2/barking (908).wav을(를) ./test4/barking/barking (908).wav로 이동했습니다.
# ./barking_2/barking (69).wav을(를) ./test4/barking/barking (69).wav로 이동했습니다.
# ./barking_2/barking (705).wav을(를) ./test4/barking/barking (705).wav로 이동했습니다.
# ./barking_2/barking (149).wav을(를) ./test4/barking/barking (149).wav로 이동했습니다.
# ./barking_2/barking (905).wav을(를) ./test4/barking/barking (905).wav로 이동했습니다.
# ./barking_2/barking (958).wav을(를) ./test4/barking/barking (958).wav로 이동했습니다.
# ./barking_2/barking (374).wav을(를) ./test4/barking/barking (374).wav로 이동했습니다.
# ./barking_2/barking (577).wav을(를) ./test4/barking/barking (577).wav로 이동했습니다.
# ./barking_2/barking (737).wav을(를) ./test4/barking/barking (737).wav로 이동했습니다.
# ./barking_2/barking (467).wav을(를) ./test4/barking/barking (467).wav로 이동했습니다.
# ./barking_2/barking (334).wav을(를) ./test4/barking/barking (334).wav로 이동했습니다.
# ./barking_2/barking (223).wav을(를) ./test4/barking/barking (223).wav로 이동했습니다.
# ./barking_2/barking (946).wav을(를) ./test4/barking/barking (946).wav로 이동했습니다.
# ./barking_2/barking (107).wav을(를) ./test4/barking/barking (107).wav로 이동했습니다.
# ./barking_2/barking (990).wav을(를) ./test4/barking/barking (990).wav로 이동했습니다.
# ./barking_2/barking (79).wav을(를) ./test4/barking/barking (79).wav로 이동했습니다.
# ./barking_2/barking (441).wav을(를) ./test4/barking/barking (441).wav로 이동했습니다.
# ./barking_2/barking (1002).wav을(를) ./test4/barking/barking (1002).wav로 이동했습니다.
# ./barking_2/barking (217).wav을(를) ./test4/barking/barking (217).wav로 이동했습니다.
# ./barking_2/barking (650).wav을(를) ./test4/barking/barking (650).wav로 이동했습니다.
# ./barking_2/barking (182).wav을(를) ./test4/barking/barking (182).wav로 이동했습니다.
# ./barking_2/barking (548).wav을(를) ./test4/barking/barking (548).wav로 이동했습니다.
# ./barking_2/barking (15).wav을(를) ./test4/barking/barking (15).wav로 이동했습니다.
# ./barking_2/barking (584).wav을(를) ./test4/barking/barking (584).wav로 이동했습니다.
# ./barking_2/barking (800).wav을(를) ./test4/barking/barking (800).wav로 이동했습니다.
# ./barking_2/barking (895).wav을(를) ./test4/barking/barking (895).wav로 이동했습니다.
# ./barking_2/barking (421).wav을(를) ./test4/barking/barking (421).wav로 이동했습니다.
# ./barking_2/barking (1093).wav을(를) ./test4/barking/barking (1093).wav로 이동했습니다.
# ./barking_2/barking (950).wav을(를) ./test4/barking/barking (950).wav로 이동했습니다.
# ./barking_2/barking (855).wav을(를) ./test4/barking/barking (855).wav로 이동했습니다.
# ./barking_2/barking (515).wav을(를) ./test4/barking/barking (515).wav로 이동했습니다.
# ./barking_2/barking (1120).wav을(를) ./test4/barking/barking (1120).wav로 이동했습니다.
# ./barking_2/barking (811).wav을(를) ./test4/barking/barking (811).wav로 이동했습니다.
# ./barking_2/barking (613).wav을(를) ./test4/barking/barking (613).wav로 이동했습니다.
# ./barking_2/barking (759).wav을(를) ./test4/barking/barking (759).wav로 이동했습니다.
# ./barking_2/barking (329).wav을(를) ./test4/barking/barking (329).wav로 이동했습니다.
# ./barking_2/barking (715).wav을(를) ./test4/barking/barking (715).wav로 이동했습니다.
# ./barking_2/barking (739).wav을(를) ./test4/barking/barking (739).wav로 이동했습니다.
# ./barking_2/barking (129).wav을(를) ./test4/barking/barking (129).wav로 이동했습니다.
# ./barking_2/barking (761).wav을(를) ./test4/barking/barking (761).wav로 이동했습니다.
# ./barking_2/barking (309).wav을(를) ./test4/barking/barking (309).wav로 이동했습니다.
# ./barking_2/barking (121).wav을(를) ./test4/barking/barking (121).wav로 이동했습니다.
# ./barking_2/barking (740).wav을(를) ./test4/barking/barking (740).wav로 이동했습니다.
# ./barking_2/barking (997).wav을(를) ./test4/barking/barking (997).wav로 이동했습니다.
# ./barking_2/barking (81).wav을(를) ./test4/barking/barking (81).wav로 이동했습니다.
# ./barking_2/barking (728).wav을(를) ./test4/barking/barking (728).wav로 이동했습니다.
# ./barking_2/barking (675).wav을(를) ./test4/barking/barking (675).wav로 이동했습니다.
# ./barking_2/barking (666).wav을(를) ./test4/barking/barking (666).wav로 이동했습니다.
# ./barking_2/barking (478).wav을(를) ./test4/barking/barking (478).wav로 이동했습니다.
# ./barking_2/barking (459).wav을(를) ./test4/barking/barking (459).wav로 이동했습니다.
# ./barking_2/barking (471).wav을(를) ./test4/barking/barking (471).wav로 이동했습니다.
# ./barking_2/barking (332).wav을(를) ./test4/barking/barking (332).wav로 이동했습니다.
# ./barking_2/barking (598).wav을(를) ./test4/barking/barking (598).wav로 이동했습니다.
# ./barking_2/barking (359).wav을(를) ./test4/barking/barking (359).wav로 이동했습니다.
# ./barking_2/barking (869).wav을(를) ./test4/barking/barking (869).wav로 이동했습니다.
# ./barking_2/barking (378).wav을(를) ./test4/barking/barking (378).wav로 이동했습니다.
# ./barking_2/barking (959).wav을(를) ./test4/barking/barking (959).wav로 이동했습니다.
# ./barking_2/barking (1022).wav을(를) ./test4/barking/barking (1022).wav로 이동했습니다.
# ./barking_2/barking (337).wav을(를) ./test4/barking/barking (337).wav로 이동했습니다.
# ./barking_2/barking (900).wav을(를) ./test4/barking/barking (900).wav로 이동했습니다.
# ./barking_2/barking (844).wav을(를) ./test4/barking/barking (844).wav로 이동했습니다.
# ./barking_2/barking (427).wav을(를) ./test4/barking/barking (427).wav로 이동했습니다.
# ./barking_2/barking (902).wav을(를) ./test4/barking/barking (902).wav로 이동했습니다.
# ./barking_2/barking (1064).wav을(를) ./test4/barking/barking (1064).wav로 이동했습니다.
# ./barking_2/barking (351).wav을(를) ./test4/barking/barking (351).wav로 이동했습니다.
# ./barking_2/barking (933).wav을(를) ./test4/barking/barking (933).wav로 이동했습니다.
# ./barking_2/barking (90).wav을(를) ./test4/barking/barking (90).wav로 이동했습니다.
# ./barking_2/barking (519).wav을(를) ./test4/barking/barking (519).wav로 이동했습니다.
# ./barking_2/barking (771).wav을(를) ./test4/barking/barking (771).wav로 이동했습니다.
# ./barking_2/barking (241).wav을(를) ./test4/barking/barking (241).wav로 이동했습니다.
# ./barking_2/barking (494).wav을(를) ./test4/barking/barking (494).wav로 이동했습니다.
# ./barking_2/barking (1013).wav을(를) ./test4/barking/barking (1013).wav로 이동했습니다.
# ./barking_2/barking (748).wav을(를) ./test4/barking/barking (748).wav로 이동했습니다.
# ./barking_2/barking (1102).wav을(를) ./test4/barking/barking (1102).wav로 이동했습니다.
# ./barking_2/barking (203).wav을(를) ./test4/barking/barking (203).wav로 이동했습니다.
# ./barking_2/barking (489).wav을(를) ./test4/barking/barking (489).wav로 이동했습니다.
# ./barking_2/barking (86).wav을(를) ./test4/barking/barking (86).wav로 이동했습니다.
# ./barking_2/barking (1009).wav을(를) ./test4/barking/barking (1009).wav로 이동했습니다.
# ./barking_2/barking (552).wav을(를) ./test4/barking/barking (552).wav로 이동했습니다.
# ./barking_2/barking (455).wav을(를) ./test4/barking/barking (455).wav로 이동했습니다.
# ./barking_2/barking (282).wav을(를) ./test4/barking/barking (282).wav로 이동했습니다.
# ./barking_2/barking (461).wav을(를) ./test4/barking/barking (461).wav로 이동했습니다.
# ./barking_2/barking (126).wav을(를) ./test4/barking/barking (126).wav로 이동했습니다.
# ./barking_2/barking (485).wav을(를) ./test4/barking/barking (485).wav로 이동했습니다.
# ./barking_2/barking (295).wav을(를) ./test4/barking/barking (295).wav로 이동했습니다.
# ./barking_2/barking (220).wav을(를) ./test4/barking/barking (220).wav로 이동했습니다.
# ./barking_2/barking (768).wav을(를) ./test4/barking/barking (768).wav로 이동했습니다.
# ./barking_2/barking (253).wav을(를) ./test4/barking/barking (253).wav로 이동했습니다.
# ./barking_2/barking (8).wav을(를) ./test4/barking/barking (8).wav로 이동했습니다.
# ./barking_2/barking (887).wav을(를) ./test4/barking/barking (887).wav로 이동했습니다.
# ./barking_2/barking (141).wav을(를) ./test4/barking/barking (141).wav로 이동했습니다.
# ./barking_2/barking (160).wav을(를) ./test4/barking/barking (160).wav로 이동했습니다.
# ./barking_2/barking (798).wav을(를) ./test4/barking/barking (798).wav로 이동했습니다.
# ./barking_2/barking (1057).wav을(를) ./test4/barking/barking (1057).wav로 이동했습니다.
# ./barking_2/barking (755).wav을(를) ./test4/barking/barking (755).wav로 이동했습니다.
# ./barking_2/barking (61).wav을(를) ./test4/barking/barking (61).wav로 이동했습니다.
# ./barking_2/barking (11).wav을(를) ./test4/barking/barking (11).wav로 이동했습니다.
# ./barking_2/barking (287).wav을(를) ./test4/barking/barking (287).wav로 이동했습니다.
# ./barking_2/barking (157).wav을(를) ./test4/barking/barking (157).wav로 이동했습니다.
# ./barking_2/barking (816).wav을(를) ./test4/barking/barking (816).wav로 이동했습니다.
# ./barking_2/barking (570).wav을(를) ./test4/barking/barking (570).wav로 이동했습니다.
# ./barking_2/barking (929).wav을(를) ./test4/barking/barking (929).wav로 이동했습니다.
# ./barking_2/barking (192).wav을(를) ./test4/barking/barking (192).wav로 이동했습니다.
# ./barking_2/barking (446).wav을(를) ./test4/barking/barking (446).wav로 이동했습니다.
# ./barking_2/barking (197).wav을(를) ./test4/barking/barking (197).wav로 이동했습니다.
# ./barking_2/barking (64).wav을(를) ./test4/barking/barking (64).wav로 이동했습니다.
# ./barking_2/barking (431).wav을(를) ./test4/barking/barking (431).wav로 이동했습니다.
# ./barking_2/barking (860).wav을(를) ./test4/barking/barking (860).wav로 이동했습니다.
# ./barking_2/barking (684).wav을(를) ./test4/barking/barking (684).wav로 이동했습니다.
# ./barking_2/barking (1078).wav을(를) ./test4/barking/barking (1078).wav로 이동했습니다.
# ./barking_2/barking (861).wav을(를) ./test4/barking/barking (861).wav로 이동했습니다.
# ./barking_2/barking (805).wav을(를) ./test4/barking/barking (805).wav로 이동했습니다.
# ./barking_2/barking (423).wav을(를) ./test4/barking/barking (423).wav로 이동했습니다.
# ./barking_2/barking (495).wav을(를) ./test4/barking/barking (495).wav로 이동했습니다.
# ./barking_2/barking (304).wav을(를) ./test4/barking/barking (304).wav로 이동했습니다.
# ./barking_2/barking (542).wav을(를) ./test4/barking/barking (542).wav로 이동했습니다.
# ./barking_2/barking (191).wav을(를) ./test4/barking/barking (191).wav로 이동했습니다.
# ./barking_2/barking (187).wav을(를) ./test4/barking/barking (187).wav로 이동했습니다.
# ./barking_2/barking (84).wav을(를) ./test4/barking/barking (84).wav로 이동했습니다.
# ./barking_2/barking (226).wav을(를) ./test4/barking/barking (226).wav로 이동했습니다.
# ./barking_2/barking (874).wav을(를) ./test4/barking/barking (874).wav로 이동했습니다.
# ./barking_2/barking (707).wav을(를) ./test4/barking/barking (707).wav로 이동했습니다.
# ./barking_2/barking (89).wav을(를) ./test4/barking/barking (89).wav로 이동했습니다.
# ./barking_2/barking (225).wav을(를) ./test4/barking/barking (225).wav로 이동했습니다.
# ./barking_2/barking (537).wav을(를) ./test4/barking/barking (537).wav로 이동했습니다.
# ./barking_2/barking (512).wav을(를) ./test4/barking/barking (512).wav로 이동했습니다.
# ./barking_2/barking (925).wav을(를) ./test4/barking/barking (925).wav로 이동했습니다.
# ./barking_2/barking (1104).wav을(를) ./test4/barking/barking (1104).wav로 이동했습니다.
# ./barking_2/barking (549).wav을(를) ./test4/barking/barking (549).wav로 이동했습니다.
# ./barking_2/barking (645).wav을(를) ./test4/barking/barking (645).wav로 이동했습니다.
# ./barking_2/barking (693).wav을(를) ./test4/barking/barking (693).wav로 이동했습니다.
# ./barking_2/barking (518).wav을(를) ./test4/barking/barking (518).wav로 이동했습니다.
# ./barking_2/barking (272).wav을(를) ./test4/barking/barking (272).wav로 이동했습니다.
# ./barking_2/barking (1040).wav을(를) ./test4/barking/barking (1040).wav로 이동했습니다.
# ./barking_2/barking (442).wav을(를) ./test4/barking/barking (442).wav로 이동했습니다.
# ./barking_2/barking (563).wav을(를) ./test4/barking/barking (563).wav로 이동했습니다.
# ./barking_2/barking (165).wav을(를) ./test4/barking/barking (165).wav로 이동했습니다.
# ./barking_2/barking (802).wav을(를) ./test4/barking/barking (802).wav로 이동했습니다.
# ./barking_2/barking (45).wav을(를) ./test4/barking/barking (45).wav로 이동했습니다.
# ./barking_2/barking (430).wav을(를) ./test4/barking/barking (430).wav로 이동했습니다.
# ./barking_2/barking (867).wav을(를) ./test4/barking/barking (867).wav로 이동했습니다.
# ./barking_2/barking (992).wav을(를) ./test4/barking/barking (992).wav로 이동했습니다.
# ./barking_2/barking (848).wav을(를) ./test4/barking/barking (848).wav로 이동했습니다.
# ./barking_2/barking (31).wav을(를) ./test4/barking/barking (31).wav로 이동했습니다.
# ./barking_2/barking (863).wav을(를) ./test4/barking/barking (863).wav로 이동했습니다.
# ./barking_2/barking (398).wav을(를) ./test4/barking/barking (398).wav로 이동했습니다.
# ./barking_2/barking (531).wav을(를) ./test4/barking/barking (531).wav로 이동했습니다.
# ./barking_2/barking (302).wav을(를) ./test4/barking/barking (302).wav로 이동했습니다.
# ./barking_2/barking (1060).wav을(를) ./test4/barking/barking (1060).wav로 이동했습니다.
# ./barking_2/barking (689).wav을(를) ./test4/barking/barking (689).wav로 이동했습니다.
# ./barking_2/barking (1016).wav을(를) ./test4/barking/barking (1016).wav로 이동했습니다.
# ./barking_2/barking (574).wav을(를) ./test4/barking/barking (574).wav로 이동했습니다.
# ./barking_2/barking (1067).wav을(를) ./test4/barking/barking (1067).wav로 이동했습니다.
# ./barking_2/barking (375).wav을(를) ./test4/barking/barking (375).wav로 이동했습니다.
# ./barking_2/barking (161).wav을(를) ./test4/barking/barking (161).wav로 이동했습니다.
# ./barking_2/barking (955).wav을(를) ./test4/barking/barking (955).wav로 이동했습니다.
# ./barking_2/barking (792).wav을(를) ./test4/barking/barking (792).wav로 이동했습니다.
# ./barking_2/barking (880).wav을(를) ./test4/barking/barking (880).wav로 이동했습니다.
# ./barking_2/barking (706).wav을(를) ./test4/barking/barking (706).wav로 이동했습니다.
# ./barking_2/barking (106).wav을(를) ./test4/barking/barking (106).wav로 이동했습니다.
# ./barking_2/barking (1083).wav을(를) ./test4/barking/barking (1083).wav로 이동했습니다.
# ./barking_2/barking (385).wav을(를) ./test4/barking/barking (385).wav로 이동했습니다.
# ./barking_2/barking (1076).wav을(를) ./test4/barking/barking (1076).wav로 이동했습니다.
# ./barking_2/barking (219).wav을(를) ./test4/barking/barking (219).wav로 이동했습니다.
# ./barking_2/barking (649).wav을(를) ./test4/barking/barking (649).wav로 이동했습니다.
# ./barking_2/barking (791).wav을(를) ./test4/barking/barking (791).wav로 이동했습니다.
# ./barking_2/barking (1007).wav을(를) ./test4/barking/barking (1007).wav로 이동했습니다.
# ./barking_2/barking (300).wav을(를) ./test4/barking/barking (300).wav로 이동했습니다.
# ./barking_2/barking (1097).wav을(를) ./test4/barking/barking (1097).wav로 이동했습니다.
# ./barking_2/barking (524).wav을(를) ./test4/barking/barking (524).wav로 이동했습니다.
